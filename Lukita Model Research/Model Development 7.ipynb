# %%
! pip install DeepImageSearch -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 93.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.1 MB/s eta 0:00:00
# ...

# %%
! pip install DeepImageSearch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project
# Out:
# /content/drive/MyDrive/Project

# %%
from DeepImageSearch import Load_Data, Search_Setup

# %%
# Load images from a folder
image_list = Load_Data().from_folder(['/content/drive/MyDrive/Project/new_dataset'])

# %%
image_list[:5]
# Out:
# ['/content/drive/MyDrive/Project/new_dataset/Symbolism/192847.jpg',
#  '/content/drive/MyDrive/Project/new_dataset/Symbolism/192865.jpg',
#  '/content/drive/MyDrive/Project/new_dataset/Symbolism/192936.jpg',
#  '/content/drive/MyDrive/Project/new_dataset/Symbolism/194255.jpg',
#  '/content/drive/MyDrive/Project/new_dataset/Symbolism/192958.jpg']

# %%
# Set up the search engine, You can load 'vit_base_patch16_224_in21k', 'resnet50' etc more then 500+ models 
st = Search_Setup(image_list=image_list, model_name='vgg19', pretrained=True, image_count=100)
# Out:
#  Please Wait Model Is Loading or Downloading From Server!
#  Model Loaded Successfully: vgg19

# %%
# Index the images
st.run_index()
# Out:
#  Metadata and Features are already present, Do you want Extract Again? Enter yes or no
# yes
# 100%|██████████| 100/100 [02:10<00:00,  1.30s/it]
#  Image Meta Information Saved: [metadata-files/vgg19/image_data_features.pkl]
#  Saved The Indexed File:[metadata-files/vgg19/image_features_vectors.idx]

# %%
# Get metadata
metadata = st.get_image_metadata_file()

# %%
# Get similar images
st.get_similar_images(image_path='/content/drive/MyDrive/Project/new_dataset/Symbolism/296790.jpg', number_of_images=5)
# Out:
# {83: '/content/drive/MyDrive/Project/new_dataset/Symbolism/296790.jpg',
#  22: '/content/drive/MyDrive/Project/new_dataset/Symbolism/239175.jpg',
#  80: '/content/drive/MyDrive/Project/new_dataset/Symbolism/296767.jpg',
#  81: '/content/drive/MyDrive/Project/new_dataset/Symbolism/9223372032559856083.jpg',
#  14: '/content/drive/MyDrive/Project/new_dataset/Symbolism/194367.jpg'}

# %%
# Plot similar images
st.plot_similar_images(image_path='/content/drive/MyDrive/Project/new_dataset/Symbolism/296790.jpg', number_of_images=5)
